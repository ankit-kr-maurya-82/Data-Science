# %%
# Logistic Regression

# %%
# result Status

# %%
import module as md
data={
    "Marks": [35,45,55,65,75],
    "StudyHours":[1,2,3,4,5],
    "Attendance": [50,60,70,80,90],
    "Result": ["Fail", "Fail", "Pass", "Pass","Pass"]
}

df=md.pd.DataFrame(data)
print(df)

x=df[["Marks", "StudyHours", "Attendance"]]
y=df["Result"]

model= md.LogisticRegression()
model.fit(x,y)

marks=float(input("Enter Marks: "))
hours=float(input("Enter Study Hours: "))
attendance=float(input("Enter Attendance: "))

prediction= model.predict([[marks, hours, attendance]])
print("Prediction:", prediction[0])
probability=model.predict_proba([[marks, hours, attendance]])

print("Probability:")
print("Fail Probability:", round(probability[0][0]*100,2), "%")
print("Pass Probability:", round(probability[0][1]*100,2), "%")


y_pred = model.predict(x)
accuracy= accuracy_score(y,y_pred)
print("Accuracy: ", accuracy * 100, "%")
# Out:
#    Marks  StudyHours  Attendance Result
# 0     35           1          50   Fail
# 1     45           2          60   Fail
# 2     55           3          70   Pass
# 3     65           4          80   Pass
# 4     75           5          90   Pass
# d:\2 SEM\Python\.venv\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# d:\2 SEM\Python\.venv\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# Prediction: Fail
# Probability:
# Fail Probability: 99.04 %
# Pass Probability: 0.96 %
# Accuracy:  100.0 %

# %%
# Loan Approval / Rejection

# %%
data = {
    'Income': [20000, 25000, 30000, 35000, 40000, 45000, 50000, 55000, 60000, 65000],
    'CreditScore': [500, 550, 580, 600, 620, 650, 680, 700, 720, 750],
    'LoanAmount': [50000, 60000, 70000, 80000, 90000, 100000, 110000, 120000, 130000, 140000],
    'Status': ['Rejected', 'Rejected', 'Rejected', 'Rejected', 'Approved', 'Approved', 'Approved', 'Approved', 'Approved', 'Approved']
}



df=md.pd.DataFrame(data)
print(df)

x=df[["Income", "CreditScore", "LoanAmount"]]
y=df["Status"]

model= md.LogisticRegression()
model.fit(x,y)

income=float(input("Enter income: "))
credit_score=float(input("Enter credit score: "))
loan_amt=float(input("Enter Loan Amount: "))

prediction= model.predict([[income, credit_score, loan_amt]])
print("Prediction:", prediction[0])
probability=model.predict_proba([[income, credit_score, loan_amt]])

print("Probability:")
print("Reject Probability:", round(probability[0][0]*100,2), "%")
print("Approve Probability:", round(probability[0][1]*100,2), "%")


y_pred = model.predict(x)
accuracy= accuracy_score(y,y_pred)
print("Accuracy: ", accuracy * 100, "%")
# Out:
#    Income  CreditScore  LoanAmount    Status
# 0   20000          500       50000  Rejected
# 1   25000          550       60000  Rejected
# 2   30000          580       70000  Rejected
# 3   35000          600       80000  Rejected
# 4   40000          620       90000  Approved
# 5   45000          650      100000  Approved
# 6   50000          680      110000  Approved
# 7   55000          700      120000  Approved
# 8   60000          720      130000  Approved
# 9   65000          750      140000  Approved
# Prediction: Approved
# Probability:
# Reject Probability: 100.0 %
# Approve Probability: 0.0 %
# Accuracy:  100.0 %
# d:\2 SEM\Python\.venv\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# ...

# %%
# loan Approval dataset

# %%
data
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0           1                  2       Graduate             No        9600000
# 1           2                  0   Not Graduate            Yes        4100000
# 2           3                  3       Graduate             No        9100000
# 3           4                  3       Graduate             No        8200000
# 4           5                  5   Not Graduate            Yes        9800000
# ...       ...                ...            ...            ...            ...
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.sample()
# Out:
#      loan_id   no_of_dependents  education  self_employed   income_annum  \
# 640      641                  3   Graduate             No        4600000
#
#       loan_amount   loan_term   cibil_score   residential_assets_value  \
# 640      17800000          20           716                   12600000
#
#       commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 640                   2600000              10800000            4500000
#
#      loan_status
# 640     Approved

# %%
data.__delitem__("luxury_assets_value")
# data.__delitem__("bank_asset_value")
# data.__delitem__("commercial_assets_value")
# data.__delitem__("residential_assets_value")
# data.__delitem__("no_of_dependents")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 data.drop("luxury_assets_value")
#       2 # data.__delitem__("bank_asset_value")
#       3 # data.__delitem__("commercial_assets_value")
#       4 # data.__delitem__("residential_assets_value")
#       5 # data.__delitem__("no_of_dependents")
#
# File d:\2 SEM\Python\.venv\Lib\site-packages\pandas\core\frame.py:6300, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6142 def drop(
#    6143     self,
#    6144     labels: IndexLabel | ListLike = None,
#    (...)   6151     errors: IgnoreRaise = "raise",
#    6152 ) -> DataFrame | None:
#    6153     """
#    6154     Drop specified labels from rows or columns.
#    6155
#    (...)   6298             weight  1.0     0.8
#    6299     """
# -> 6300     return super().drop(
#    6301         labels=labels,
# ...

# %%
data
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0           1                  2       Graduate             No        9600000
# 1           2                  0   Not Graduate            Yes        4100000
# 2           3                  3       Graduate             No        9100000
# 3           4                  3       Graduate             No        8200000
# 4           5                  5   Not Graduate            Yes        9800000
# ...       ...                ...            ...            ...            ...
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
# ...
