# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("full_grouped.csv")

# %%
data.tail()
# Out:
#              Date      Country/Region  Confirmed  Deaths  Recovered  Active  \
# 35151  2020-07-27  West Bank and Gaza      10621      78       3752    6791
# 35152  2020-07-27      Western Sahara         10       1          8       1
# 35153  2020-07-27               Yemen       1691     483        833     375
# 35154  2020-07-27              Zambia       4552     140       2815    1597
# 35155  2020-07-27            Zimbabwe       2704      36        542    2126
#
#        New cases  New deaths  New recovered             WHO Region
# 35151        152           2              0  Eastern Mediterranean
# 35152          0           0              0                 Africa
# 35153         10           4             36  Eastern Mediterranean
# 35154         71           1            465                 Africa
# 35155        192           2             24                 Africa

# %%
data["Deaths"].max()
# Out:
# np.int64(148011)

# %%
data["Deaths"].min()
# Out:
# np.int64(0)

# %%
data["Recovered"].max()
# Out:
# np.int64(1846641)

# %%
data["Recovered"].min()
# Out:
# np.int64(0)

# %%
data["New deaths"].max()
# Out:
# np.int64(3887)

# %%
data["New cases"].max()
# Out:
# np.int64(77255)

# %%
data["New recovered"].max()
# Out:
# np.int64(140050)

# %%
data.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
data["Date"].max()
# Out:
# '2020-07-27'

# %%
data["Date"].min()
# Out:
# '2020-01-22'

# %%
data["WHO Region"].count()
# Out:
# np.int64(35156)

# %%
data["WHO Region"].max()
# Out:
# 'Western Pacific'

# %%
data["WHO Region"].min()
# Out:
# 'Africa'

# %%
data["Active"].tail().max()
# Out:
# np.int64(6791)

# %%
# Detect Outliers
plt.figure(figsize=(8,4))
plt.boxplot(data["Deaths"])
plt.title("Boxplot of Deaths")
plt.ylabel("Deaths")
plt.show()

# %%
# Detect Outliers
plt.figure(figsize=(8,4))
plt.boxplot(data["Recovered"])
plt.title("Boxplot of Recovered")
plt.ylabel("Recovered")
plt.show()

# %%
# Detect Outliers
plt.figure(figsize=(8,4))
plt.boxplot(data["New cases"])
plt.title("Boxplot of New Cases")
plt.ylabel("New Cases")
plt.show()

# %%
plt.scatter(
    data["Deaths"],
    data["Recovered"]
)

plt.title("Deaths and Recovered")
plt.show()

# %%
pd.crosstab(data["Date"], data["Recovered"]).median()
# Out:
# Recovered
# 0          12.0
# 1           1.0
# 2           1.0
# 3           0.0
# 4           1.0
#            ...
# 1620313     0.0
# 1693214     0.0
# 1785359     0.0
# 1812913     0.0
# 1846641     0.0
# Length: 7649, dtype: float64

# %%
plt.plot(data['Deaths'], )
plt.plot(data['New cases'])
plt.plot(data['New recovered'])

# %%
# showing explore
death=data["Deaths"]
region=data["Country/Region"]
plt.bar(region,death)


plt.show()

# %%
# showing explore
death=data["Date"]
region=data["Deaths"]
plt.bar(death,region)


plt.show()

# %%
# showing explore
date=data["New recovered"]
death=data["New cases"]
plt.plot(date,label="date")
plt.plot(death,label="death")
plt.grid(True)

plt.show()
