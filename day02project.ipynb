# %%
def line(n=45):
  print("="*n)

line()

print("\t\tUNIVERSITY MANAGEMENT SYSTEM")
line()

name=input('Enter Student Name : ')
rollNo=input('Enter Roll Number : ')

def menu():
    print("\n===== MENU =====")
    print("1. Result Calculator")
    print("2. Attendance Checker")
    print("3. Scholarship Checker")

menu()

choice= int(input("Enter your choice : "))

if choice==1:
  print("\n=====Result Calculator=====")
  py=int(input("Enter Python Marks : "))
  maths=int(input("Enter Maths Marks : "))
  eng=int(input("Enter English Marks : "))
  total=py+maths+eng
  per=total/3
  print("Percentage : ",per)
elif choice==2:
  print("\n=====Attendance Checker=====")
  total_days=200
  attend_days=int(input("Enter attend days: "))
  print("\n")
  print("="*40)
  print("Name:", name)
  print("total days:", total_days)
  print("attend days:", attend_days)
elif choice==3:
  print("\n=====Scholarship Checker")
  result_percentage=float(input("Enter percentage of scholar: "))
  if result_percentage>=90 and result_percentage<=100:
    print(f"{name} scholar is 100%")
  elif result_percentage>=80 and result_percentage<=89:
    print(f"{name} scholar is 85%")
  elif result_percentage>=70 and result_percentage<=79:
    print(f"{name} scholar is 75%")
    4
  elif result_percentage>=60 and result_percentage<=694:
    print(f"{name} scholar is 65%")
  elif result_percentage>=50 and result_percentage<=59:
    print(f"{name} scholar is 50%")
  elif result_percentage>=40 and result_percentage<=49:
    print(f"{name} scholar is 45%")
  elif result_percentage>=30 and result_percentage<=39:
    print(f"{name} scholar is 30%")
  else:
    print(f"{name} has no scholarship!")
else:
  print("Invalid Number: ")
# Out:
# ...
#       UNIVERSITY MANAGEMENT SYSTEM
# ...
#
# ===== MENU =====
# 1. Result Calculator
# 2. Attendance Checker
# 3. Scholarship Checker
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 17
#      14 print("2. Attendance Checker")
#      15 print("3. Scholarship Checker")
# ---> 17 choice= int(input("Enter your choice : "))
#      19 if choice==1:
#      20   print("\n=====Result Calculator=====")
#
# ValueError: invalid literal for int() with base 10: ''
