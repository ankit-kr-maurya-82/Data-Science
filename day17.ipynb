# %%
import numpy as np

# Sigmoid activation function
def sigmoid(x):
  return 1/(1+np.exp(-x))

X=np.array([
    [0,0],
    [0,1],
    [1,0],
    [1,1]
])

y=np.array([[0], [0], [0], [1]])

# Initialize weights and bias
weights=np.random.rand(2,1)
bias=np.random.rand(1)
learning_rate=0.1

# Training the neural network
for epoch in range(10000):
  z=np.dot(X, weights)+bias
  y_pred=sigmoid(z)

  error=y-y_pred
  gradient=y_pred * (1-y_pred)

  weights+=learning_rate * np.dot(X.T*gradient)
  bias += learning_rate*np.sum(error*gradient)

  # Testing
  print("AND Gate Output:")
  for i in X:
    output=sigmoid(np.dot(i,weights)+bias)
    print(i,"->", round(output[0]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 29
#      25
#      26   error=y-y_pred
#      27   gradient=y_pred * (1-y_pred)
#      28
# ---> 29   weights+=learning_rate * np.dot(X.T*gradient)
#      30   bias += learning_rate*np.sum(error*gradient)
#      31
#      32   # Testing
#
# ValueError: operands could not be broadcast together with shapes (2,4) (4,1)

# %%
import pandas as pd
import numpy as np




data = {
    "Study_Hours": [6,5,4,3,2,1,6,6,4,5],
    "Attendance": [45,65,34,65,34,67,56,56,76,45],
    "Previous_Marks": [98,67,56,88,78,67,67,87,56,98],
    "Pass": [1,1,0,0,1,0,1,0,0,1]
}

df = pd.DataFrame(data)


x=df[["Study_Hours", "Attendance", "Previous_Marks"]]
y=df[]
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement tensorflow (from versions: none)
# ERROR: No matching distribution found for tensorflow
