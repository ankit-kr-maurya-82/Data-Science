# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data= pd.read_csv("Mall_Customers.csv")
data
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
data["CustomerID"]
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 195    196
# 196    197
# 197    198
# 198    199
# 199    200
# Name: CustomerID, Length: 200, dtype: int64

# %%
data["CustomerID"].count()
# Out:
# np.int64(200)

# %%
data.isnull().sum()
# Out:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
a = data["Spending Score (1-100)"].median()
a
# Out:
# np.float64(50.0)

# %%
m=data['Genre']
m
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3      Female
# 4      Female
#         ...
# 195    Female
# 196    Female
# 197      Male
# 198      Male
# 199      Male
# Name: Genre, Length: 200, dtype: str

# %%
pd.crosstab(data["Genre"], data["Age"])
# Out:
# Age     36.0
# Genre
# Female   112
# Male      88

# %%
data["Age"].min()
# Out:
# np.float64(36.0)

# %%
data["Age"].max()
# Out:
# np.float64(36.0)

# %%
data["Age"].min()
# Out:
# np.float64(36.0)

# %%
gen=data["Annual Income (k$)"]
age=data['Spending Score (1-100)']
plt.hist(gen,labels=age)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 3
#       1 gen=data["Annual Income (k$)"]
#       2 age=data['Spending Score (1-100)']
# ----> 3 plt.hist(gen,labels=age)
#       4 plt.show()
#
#     [... skipping hidden 1 frame]
#
# File d:\2 SEM\Python\.venv\Lib\site-packages\matplotlib\pyplot.py:3661, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3636 @_copy_docstring_and_deprecators(Axes.hist)
#    3637 def hist(
#    3638     x: ArrayLike | Sequence[ArrayLike],
#    (...)   3659     BarContainer | Polygon | list[BarContainer | Polygon],
#    3660 ]:
# -> 3661     return gca().hist(
#    3662         x,
#    3663         bins=bins,
#    3664         range=range,
#    3665         density=density,
#    3666         weights=weights,
# ...

# %%
import seaborn as sns
corr=data.corr(numeric_only=True)
sns.heatmap(corr)
