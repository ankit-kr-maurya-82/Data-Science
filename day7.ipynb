# %%
import numpy as jtn

# %%
j1=jtn.arange(3,10,2)
print(j1)
j1[1]
j1[3]
j1[-1]
# Out:
# [3 5 7 9]
# np.int64(9)

# %%
j1=jtn.random.rand(2,3)*100
j1
# Out:
# array([[23.35600732, 25.01825718, 34.94847498],
#        [ 8.73624088, 47.43202487, 61.15808178]])

# %%
j1=(jtn.random.rand(3,3)*100).astype(int)
j1
# Out:
# array([[99, 80, 46],
#        [23, 48, 13],
#        [73, 92, 48]])

# %%
j1=(jtn.random.rand(4,4)*100).astype(int)
j1
print(j1)
j1[:,0]     # jtn(row,col)
j1[2,:]
j1[0,:]
j1[:,3]
j1[:,3:1]
j1[:]
# Out:
# [[53 85 33 80]
#  [43 30 92 84]
#  [86 25  9 85]
#  [61 46 87 74]]
# array([[53, 85, 33, 80],
#        [43, 30, 92, 84],
#        [86, 25,  9, 85],
#        [61, 46, 87, 74]])

# %%
j1=(jtn.random.rand(5,5)*100).astype(int)
print(j1)
j1[:]                   #all
j1[0]                   # first row
j1[-1]                  # last row
j1[:3]                  # first 3 row
j1[-3:]                 # last 3 row
j1[2:6]                 # element from  2 to 5
j1[3:]                 # element from  3 to end
j1[:5]                 # element f rom  start to index 4
# Out:
# [[39 19 37 81 53]
#  [42 77 94 41 93]
#  [65 31 50 60 12]
#  [44 10 99 90  6]
#  [95 48 37 98 71]]
# array([[39, 19, 37, 81, 53],
#        [42, 77, 94, 41, 93],
#        [65, 31, 50, 60, 12],
#        [44, 10, 99, 90,  6],
#        [95, 48, 37, 98, 71]])

# %%
# 2d array
j1=(jtn.random.rand(3,3)*100).astype(int)
print(j1)
j1[0]
j1[1]
j1[2]
j1[-1]
j1[0:2]
j1[1:]
j1[0:3]
j1[1,:]
j1[2,:]
j1[:,:]
# Out:
# [[56 97 14]
#  [39 53 21]
#  [86 56 15]]
# array([[56, 97, 14],
#        [39, 53, 21],
#        [86, 56, 15]])

# %%
j1=(jtn.random.rand(3,3)*100).astype(int)
print(j1)
j1[1,1:2]
j1[2,1:2]
j1[1,0:1]
# Out:
# [[ 0 73 16]
#  [20 30 90]
#  [38  1 29]]
# array([20])

# %%
j1=(jtn.random.rand(3,3)*100).astype(int)
print(j1)
j1[0:2,0:2]
j1[1:3,1:3]
j1[0:,0:2]
# Out:
# [[57 63 37]
#  [65 42 65]
#  [56 60 70]]
# array([[57, 63],
#        [65, 42],
#        [56, 60]])

# %%
j1=(jtn.random.rand(4,4)*100).astype(int)
print(j1)
j1[2:4,0:2]
j1[1:,2:4]
# Out:
# [[94 71 60  9]
#  [55 42 36 70]
#  [95 26 46 34]
#  [63  0 85 21]]
# array([[36, 70],
#        [46, 34],
#        [85, 21]])

# %%
# 3d array

# %%
j1=(jtn.random.rand(3,3,3)*100).astype(int)
print(j1)
j1[2,1,1]
# Out:
# [[[41 75 23]
#   [34 82 50]
#   [ 9 89 75]]
#
#  [[11 49 17]
#   [34  7 36]
#   [88 10  4]]
#
#  [[98 84 34]
#   [36 68 62]
#   [10 21 67]]]
# np.int64(68)

# %%
# Aggregation Function

# %%
import math
j1=jtn.array([10,20,13,12,19])
print(j1)
sum(j1)
min(j1)
max(j1)
jtn.var(j1)
jtn.mean(j1)
jtn.median(j1)
# Out:
# [10 20 13 12 19]
# np.float64(13.0)

# %% [markdown]
# ## Pandas

# %%
pip install pandas

# %%
import pandas as putin
import numpy as nutin

# %%
p1=putin.Series([10,20,30,40,50])
p1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
n1=nutin.array([10,20,30,40,50])
p1=putin.Series(n1)
p1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
d1={
    "name": "jakala",
    "course": "BCA",
    "Rollno": 1234,
    "address": "jaouse"
}

p1=putin.Series(d1)
p1
# Out:
# name       jakala
# course        BCA
# Rollno       1234
# address    jaouse
# dtype: object

# %%
import numpy as np
import pandas as pd


#Series

n1=np.array([10,20,30,40,50])
p1=pd.Series(n1,index=["a","b", "c", "d","e"])
print(n1)
print(p1)
p1["c"]
p1[["a","c", "e"]]
# Out:
# [10 20 30 40 50]
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64
# a    10
# c    30
# e    50
# dtype: int64

# %%
s1=pd.Series(np.arange(2,9,2))
s1
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# dtype: int64

# %%
s1=pd.Series(np.arange(2,9))
print(s1)
s1[1:5]
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# 4    6
# 5    7
# 6    8
# dtype: int64
# 1    3
# 2    4
# 3    5
# 4    6
# dtype: int64

# %%
s1=pd.Series([10,20,30,40,50],index=["a","b","c",'d',"e"], name="ankit")
print(s1)
s1.index
s1.values
s1.dtype
s1.shape
s1.size
s1.ndim
s1.name
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# Name: ankit, dtype: int64
# 'ankit'

# %%
s1=pd.Series([10,20,30,40,50],index=["a","b","c",'d',"e"], name="ankit")
print(s1)
sum(s1)
np.mean(s1)
np.median(s1)
# mode(s1)
# min(s1)
# max(s1)
# count(s1)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# Name: ankit, dtype: int64
# np.float64(30.0)

# %%
import pandas as pd
import numpy as np

s1 = pd.Series([10, 20, 30, 40, 50], index=["a", "b", "c", 'd', "e"], name="ankit")

print(s1.mode()) 

print(s1.count())
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: ankit, dtype: int64
# 5

# %%
import numpy as np
import pandas as pd

# Dataframe
d1={
    "name": ["putin", "jutin"],
      "city":["kota","delhi"],
    "age":[34,23]
}
all=pd.DataFrame(d1)
all
# Out:
#     name   city  age
# 0  putin   kota   34
# 1  jutin  delhi   23

# %%
import numpy as np
import pandas as pd

# Dataframe
d1={
    "name": ["putin", "jutin"],
      "city":["kota","delhi"],
    "age":[34,23]
}
all=pd.DataFrame(d1,columns=["n", 'c',"c"])
all
# Out:
# Empty DataFrame
# Columns: [n, c, c]
# Index: []

# %%
file=pd.read_csv("Pokemon.csv")
file
# Out:
#       number                  name    type1   type2  total   hp  attack  \
# 0          1             Bulbasaur    Grass  Poison    318   45      49
# 1          2               Ivysaur    Grass  Poison    405   60      62
# 2          3              Venusaur    Grass  Poison    525   80      82
# 3          3         Mega Venusaur    Grass  Poison    625   80     100
# 4          3   Gigantamax Venusaur    Grass  Poison    525   80      82
# ...      ...                   ...      ...     ...    ...  ...     ...
# 1067     896             Glastrier      Ice     NaN    580  100     145
# 1068     897             Spectrier    Ghost     NaN    580  100      65
# 1069     898               Calyrex  Psychic   Grass    500  100      80
# 1070     898     Ice Rider Calyrex  Psychic     Ice    680  100     165
# 1071     898  Shadow Rider Calyrex  Psychic   Ghost    680  100      85
#
#       defense  sp_attack  sp_defense  speed  generation  legendary
# ...

# %%
pk=pd.DataFrame(file)
p1=pd.Series(pk["name"])
p1
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3              Mega Venusaur
# 4        Gigantamax Venusaur
#                 ...
# 1067               Glastrier
# 1068               Spectrier
# 1069                 Calyrex
# 1070       Ice Rider Calyrex
# 1071    Shadow Rider Calyrex
# Name: name, Length: 1072, dtype: str

# %%
file=pd.read_json("train.json")
file
# Out:
#     train_no                        train_name  \
# 0      13240                Kota-Patna Express
# 1      13238                Kota-Patna Express
# 2      13237                Patna-Kota Express
# 3      13239                Patna-Kota Express
# 4      12239             Hisar Duronto Express
# 5      12465           Ranthambhore SF Express
# 6      22933                 Jaipur SF Express
# 7      22935                 Jaipur SF Express
# 8      12955  Mumbai Central Jaipur SF Express
# 9      67890           Kolkata-Delhi Superfast
# 10     12904                Golden Temple Mail
# 11     12622                Tamil Nadu Express
# 12     10622    Delhi Chennai Rajdhani Express
# 13     12424        Dibrugarh Rajdhani Express
# 14     20506        Dibrugarh Rajdhani Express
# 15     20503        New Delhi Rajdhani Express
# 16     10324        Dibrugarh Rajdhani Express
# 17     10623            Delhi Rajdhani Express
# 18     15667                  Kamakhya Express
# ...

# %%
pk=pd.DataFrame(file)
p1=pd.Series(pk["route_code"])
p1
# Out:
# 0     {'KOTA': 'Kota', 'IDG': 'Indargarh Sumerganj M...
# 1     {'KOTA': 'Kota', 'IDG': 'Indargarh Sumerganj M...
# 2     {'PNBE': 'Patna', 'DNR': 'Danapur', 'BTA': 'Bi...
# 3     {'PNBE': 'Patna', 'DNR': 'Danapur', 'BTA': 'Bi...
# 4     {'RTM': 'Ratlam', 'KOTA': 'Kota', 'SWM': 'Sawa...
# 5     {'DKAE': 'Dakaniya Talav', 'KOTA': 'Kota', 'KP...
# 6     {'BDTS': 'Bandra Terminus', 'BVI': 'Borivali',...
# 7     {'SWM': 'Sawai Madhopur', 'KOTA': 'Kota', 'RMA...
# 8     {'BCT': 'Mumbai Central', 'BVI': 'Borivali', '...
# 9     {'Kolkata': 'Kolkata', 'PNBE': 'Patna', 'BSB':...
# 10    {'NZM': 'Hazrat Nizamuddin', 'FDB': 'Faridabad...
# 11    {'NDLS': 'New Delhi', 'AGC': 'Agra Cantt', 'GW...
# 12    {'NDLS': 'New Delhi', 'JP': 'Jaipur', 'KOTA': ...
# 13    {'NDLS': 'New Delhi', 'JNU': 'Jaunpur Junction...
# 14    {'NDLS': 'New Delhi', 'MB': 'Moradabad', 'BE':...
# 15    {'DBRG': 'Dibrugarh', 'NLP': 'North Lakhimpur'...
# 16    {'DBRG': 'Dibrugarh', 'DMV': 'Dimapur', 'RNY':...
# ...
