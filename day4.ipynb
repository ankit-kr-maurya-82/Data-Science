# %%
l1=[10,20,30,[40,50]]
l2=l1.copy()
l2.append(500)
print(l1)
print(l2)
print(id(l1))
print(id(l2))
print(id(l1[3]))
print(id(l2[3]))
# Out:
# [10, 20, 30, [40, 50]]
# [10, 20, 30, [40, 50], 500]
# 2791856224640
# 2791856211072
# 2791856219136
# 2791856219136

# %%
import copy
l1=[10,20,30,[40,50]]
l2= copy.deepcopy(l1)
print(id(l1))
print(id(l2))
# Out:
# 2791856058560
# 2791885486912

# %%
l1=["anfffkkt", "bhrantik"]
# l1=[40,10,20,30]
print("length: ",len(l1))
print("max: ",max(l1))
print("min: ",min(l1))
print("sum: ",sum(l1))
print("sorted: ",sorted(l1)) 
print("reversed: ", end=" ") 
for i in reversed(l1):
  print(i,end=" ")
print()
print("enumerate: ", end=" ") 
for i in enumerate(l1):
  print(i,end=" ")
print()
print("zip: ", end=" ") 
for i in zip(l1):
  print(i,end=" ")
# Out:
# length:  2
# max:  bhrantik
# min:  anfffkkt
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 6
#       4 print("max: ",max(l1))
#       5 print("min: ",min(l1))
# ----> 6 print("sum: ",sum(l1))
#       7 print("sorted: ",sorted(l1))
#       8 print("reversed: ", end=" ")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
l1=["ankit", "bhrantik", "harsh", "sujatin", 0+1]
jatin=["sajatin", "sujatan", "sujatin", "sujuti", "sujuki", "sijuka"]
a=type(l1[-1])
print(any(l1))
print(all(l1))
print(a)
# Out:
# True
# True
# <class 'int'>

# %% [markdown]
# Set

# %%
s1={10,20,30,10,20,40,10,20,30,20,40,20,10,30,20}
s1
# Out:
# {10, 20, 30, 40}
