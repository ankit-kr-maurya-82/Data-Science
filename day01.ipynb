# %%
print("Hello", end="")
print("World")
print(r"Hello World \n")

print("10\\06\\2026")
print("10", "06","2026", sep="\\")

a=10
print(type(a))

print("Name\t\tAnkit\nRollNo\t\tK27562\nSubject\t\tJava\nCollege\t\tCPU")
print(dir(int))
# Out:
# HelloWorld
# Hello World \n
# 10\06\2026
# 10\06\2026
# <class 'int'>
# Name		Ankit
# RollNo		K27562
# Subject		Java
# College		CPU
# ...
